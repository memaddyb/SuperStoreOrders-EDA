# %% [markdown]
# DATASET LINK:
# https://www.kaggle.com/datasets/aditisaxena20/superstore-sales-dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('SuperStoreOrders.csv')

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  6/1/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  5/1/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  5/1/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  8/1/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.tail()
# Out:
#              order_id  order_date ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427  31-12-2014  4/1/2015  Standard Class        Erica Bern
# 51286    MO-2014-2560  31-12-2014  5/1/2015  Standard Class         Liz Preis
# 51287  MX-2014-110527  31-12-2014  2/1/2015    Second Class  Charlotte Melton
# 51288  MX-2014-114783  31-12-2014  6/1/2015  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720  31-12-2014  4/1/2015  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  ...  \
# 51285  Corporate        California  United States      US     West  ...
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa  ...
# 51287   Consumer           Managua      Nicaragua   LATAM  Central  ...
# 51288   Consumer         Chihuahua         Mexico   LATAM    North  ...
# 51289   Consumer          Colorado  United States      US     West  ...
#
#               category sub_category  \
# ...

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.keys()
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df['order_date']=df['order_date'].astype('datetime64')
df['ship_date']=df['ship_date'].astype('datetime64')
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\2178323531.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['order_date']=df['order_date'].astype('datetime64')
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\2178323531.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['ship_date']=df['ship_date'].astype('datetime64')

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                     object
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %%
df['sales']=pd.to_numeric(df['sales'],errors='coerce')

# %%
df.dtypes
# Out:
# order_id                  object
# order_date        datetime64[ns]
# ship_date         datetime64[ns]
# ship_mode                 object
# customer_name             object
# segment                   object
# state                     object
# country                   object
# market                    object
# region                    object
# product_id                object
# category                  object
# sub_category              object
# product_name              object
# sales                    float64
# quantity                   int64
# discount                 float64
# profit                   float64
# shipping_cost            float64
# order_priority            object
# year                       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# order_id             0
# order_date           0
# ship_date            0
# ship_mode            0
# customer_name        0
# segment              0
# state                0
# country              0
# market               0
# region               0
# product_id           0
# category             0
# sub_category         0
# product_name         0
# sales             2630
# quantity             0
# discount             0
# profit               0
# shipping_cost        0
# order_priority       0
# year                 0
# dtype: int64

# %%
df['sales']=df['sales'].fillna(0)

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.nunique()
# Out:
# order_id          25035
# order_date         1430
# ship_date          1464
# ship_mode             4
# customer_name       795
# segment               3
# state              1094
# country             147
# market                7
# region               13
# product_id        10292
# category              3
# sub_category         17
# product_name       3788
# sales               993
# quantity             14
# discount             27
# profit            24575
# shipping_cost     10037
# order_priority        4
# year                  4
# dtype: int64

# %%
df['segment'].value_counts()
# Out:
# Consumer       26518
# Corporate      15429
# Home Office     9343
# Name: segment, dtype: int64

# %%
sns.countplot(x=df['segment'])
# Out:
# <AxesSubplot: xlabel='segment', ylabel='count'>

# %% [markdown]
# consumer segement is the best seller

# %%
df['region'].value_counts()
# Out:
# Central           11117
# South              6645
# EMEA               5029
# North              4785
# Africa             4587
# Oceania            3487
# West               3203
# Southeast Asia     3129
# East               2848
# North Asia         2338
# Central Asia       2048
# Caribbean          1690
# Canada              384
# Name: region, dtype: int64

# %%
plt.figure(figsize=(15,9))
sns.countplot(data=df,x='region')
# Out:
# <AxesSubplot: xlabel='region', ylabel='count'>

# %% [markdown]
# Central region has the best sales and need to improve in canada

# %%
df['customer_name'].value_counts().head(10).plot(kind='barh',title='customer name and prodcut orderd')
# Out:
# <AxesSubplot: title={'center': 'customer name and prodcut orderd'}>

# %%
customer=df['customer_name'].value_counts().head(10).index
filters=df['customer_name'].isin(customer)

# %%
filters.sum()
# Out:
# 1012

# %%
A=df[filters]

# %%
B=A.groupby('customer_name')['profit'].sum().sort_values(ascending=False)
B
# Out:
# customer_name
# Bill Eplett        7410.00530
# Brosina Hoffman    4876.93980
# Gary Hwang         3908.11510
# Patrick O'Brill    3778.36370
# Bart Watters       3595.88590
# Eric Murdock       3306.01548
# Steven Ward        2794.73160
# Muhammed Yedwab    2642.65408
# Art Ferguson       2278.30370
# Harry Greene       -291.49228
# Name: profit, dtype: float64

# %% [markdown]
# Harry Greene is in our top 10 customer but not in profit

# %%
c=pd.DataFrame(B)

# %%
c.drop(index='Harry Greene',inplace=True)

# %%
plt.pie(c['profit'],autopct='%0.2f%%',labels=c.index)
plt.show()

# %% [markdown]
# We were able to get the insight that Bill Eplett is Best customer and is providing the superstore with Profit of 21%

# %%
df['sub_category'].value_counts()
# Out:
# Binders        6152
# Storage        5059
# Art            4883
# Paper          3538
# Chairs         3434
# Phones         3357
# Furnishings    3170
# Accessories    3075
# Labels         2606
# Envelopes      2435
# Supplies       2425
# Fasteners      2420
# Bookcases      2411
# Copiers        2223
# Appliances     1755
# Machines       1486
# Tables          861
# Name: sub_category, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['sub_category'])
# Out:
# <AxesSubplot: xlabel='sub_category', ylabel='count'>

# %% [markdown]
# The best selling sub category is Binders and Tables has lowest sales

# %%
plt.figure(figsize=(10,7))
plt.pie(df['sub_category'].value_counts(),autopct='%0.1f%%',labels=df['sub_category'].value_counts().index)
plt.title('contrubation for best selling sub categories')
plt.show()

# %%
df['state'].value_counts().head(10)
# Out:
# California                2001
# England                   1499
# New York                  1128
# Texas                      985
# Ile-de-France              981
# New South Wales            781
# North Rhine-Westphalia     719
# Queensland                 717
# San Salvador               615
# Pennsylvania               587
# Name: state, dtype: int64

# %%
plt.figure(figsize=(10,8))
plt.pie(df['state'].value_counts().head(10),labels=df['state'].value_counts().head(10).keys())
plt.title('state')
plt.show()

# %% [markdown]
# top 10 consumer states

# %%
df['country'].unique()
# Out:
# array(['Algeria', 'Australia', 'Hungary', 'Sweden', 'Canada',
#        'New Zealand', 'Iraq', 'Philippines', 'United Kingdom', 'Malaysia',
#        'Guatemala', 'Iran', 'Thailand', 'Tanzania', 'Brazil', 'Mexico',
#        'Cuba', 'France', 'United States', 'Japan', 'Sudan', 'Taiwan',
#        'Indonesia', 'Vietnam', 'Angola', 'China', 'Mozambique', 'Lebanon',
#        'Singapore', 'Netherlands', 'Nigeria', 'Egypt', 'Venezuela',
#        'South Africa', 'Spain', 'India', 'Turkey', 'Austria', 'Italy',
#        'Germany', 'Nicaragua', 'Dominican Republic', 'El Salvador',
#        'Denmark', 'Saudi Arabia', 'Zambia', 'Myanmar (Burma)', 'Russia',
#        'Mongolia', 'Belgium', 'Kenya', 'Colombia', 'Estonia',
#        'Madagascar', 'Portugal', 'Morocco', 'Sierra Leone', 'Norway',
#        'Central African Republic', 'Czech Republic', 'Benin',
#        'Bangladesh', 'Panama', 'Chile', 'South Korea', 'Switzerland',
#        'Moldova', 'Uganda', 'Zimbabwe', 'Niger', 'Senegal', 'Hong Kong',
# ...

# %%
df['country'].value_counts().head(10)
# Out:
# United States     9994
# Australia         2837
# France            2827
# Mexico            2644
# Germany           2065
# China             1880
# United Kingdom    1633
# Brazil            1599
# India             1555
# Indonesia         1390
# Name: country, dtype: int64

# %% [markdown]
# top 10 consumer countries

# %%
index=df['country'].value_counts().head(10).index
values=df['country'].value_counts().head(10).values

# %%
plt.figure(figsize=(15,5))
plt.xlabel('country')
plt.ylabel('count')
sns.set_theme(style="darkgrid")
sns.barplot(x=index,y=values)
# Out:
# <AxesSubplot: xlabel='country', ylabel='count'>

# %% [markdown]
# Largest consumer country is United State

# %% [markdown]
# **What are the Top 3 Consumer Countries orders as per Segment & Category?**

# %%
df_US=df[df['country']=='United States']
df_AUS=df[df['country']=='Australia']
df_Fr=df[df['country']=='France']

# %%
B=[df_US,df_AUS,df_Fr]

# %%
for df1 in B:
    sns.countplot(x=df1['segment'],hue=df1['category'])
    plt.xlabel('segment')
    plt.show()

# %% [markdown]
# **product need of top 3 country as per category and subcategory**

# %%
for df1 in B:
    plt.figure(figsize=(15,5))
    a=sns.countplot(x=df1['category'],hue=df1['sub_category'])
    sns.move_legend(a, "right",bbox_to_anchor=(1,1),ncol=2,title=None, frameon=False,)
    plt.xlabel('category')
    plt.show()

# %% [markdown]
# **Growth over the years**

# %%
df['year'].value_counts()
# Out:
# 2014    17531
# 2013    13799
# 2012    10962
# 2011     8998
# Name: year, dtype: int64

# %%
x=df['year'].unique()
x
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
y=[]

# %%
df_2011=df[df['year']==2011]
y.append(df_2011['quantity'].sum())

# %%
df_2012=df[df['year']==2012]
y.append(df_2012['quantity'].sum())

# %%
df_2013=df[df['year']==2013]
y.append(df_2013['quantity'].sum())

# %%
df_2014=df[df['year']==2014]
y.append(df_2014['quantity'].sum())

# %%
y
# Out:
# [31443, 38111, 48136, 60622]

# %%
sns.barplot(x=x,y=y)
plt.ylabel('Growth in sales of product')
# Out:
# Text(0, 0.5, 'Growth in sales of product')

# %% [markdown]
# **for each year sales are increasing**

# %%
df['category'].value_counts()
# Out:
# Office Supplies    31273
# Technology         10141
# Furniture           9876
# Name: category, dtype: int64

# %%
df.groupby('category').sum()['profit'].plot(kind='bar')
plt.ylabel('in millions')
plt.show()
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\2226685869.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('category').sum()['profit'].plot(kind='bar')

# %% [markdown]
# **Technology is the most profitable category**

# %%
df.groupby('market').sum()['profit'].plot(kind='bar')
plt.ylabel('in millions')
plt.show()
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\4131305143.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('market').sum()['profit'].plot(kind='bar')

# %% [markdown]
# **APAC is the most profitable market**

# %%
df.groupby(['country']).sum()[['profit']].sort_values(by="profit",ascending=False).head(10).plot.bar()
plt.show()
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\275438612.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['country']).sum()[['profit']].sort_values(by="profit",ascending=False).head(10).plot.bar()

# %% [markdown]
# **Top 10 profitable country**

# %%
pd.DataFrame(df.groupby(['product_name']).sum()[['quantity']].sort_values(by='quantity',ascending=False).head(10)).plot(kind='bar')
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\4169711397.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(df.groupby(['product_name']).sum()[['quantity']].sort_values(by='quantity',ascending=False).head(10)).plot(kind='bar')
# <AxesSubplot: xlabel='product_name'>

# %% [markdown]
# **Top 10 products which have highest sales count**

# %%
df['ship_mode'].value_counts()
# Out:
# Standard Class    30775
# Second Class      10309
# First Class        7505
# Same Day           2701
# Name: ship_mode, dtype: int64

# %%
df['ship_mode'].value_counts().plot.pie()
# Out:
# <AxesSubplot: ylabel='ship_mode'>

# %% [markdown]
# **most choosen shipment mode is Standard Class **

# %%
df.groupby(['region']).sum()['discount'].nlargest(5).plot.bar()
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\3687888175.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['region']).sum()['discount'].nlargest(5).plot.bar()
# <AxesSubplot: xlabel='region'>

# %% [markdown]
# **Central regions has given highest discount**

# %%
df.groupby(['region']).sum()['profit'].nlargest(5).plot.bar()
# Out:
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\713610036.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['region']).sum()['profit'].nlargest(5).plot.bar()
# <AxesSubplot: xlabel='region'>

# %% [markdown]
# Central region has given highest discount also havinh highest profit

# %%
df_profit=df[df['profit'] > 0].sum()
profit=df_profit['profit'].sum()
print('Total profit',df_profit['profit'].sum())
# Out:
# Total profit 2389392.212
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\3883633905.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_profit=df[df['profit'] > 0].sum()

# %%
df_profit=df[df['profit'] < 0].sum()
loss=df_profit['profit'].sum()
print('Total loss',df_profit['profit'].sum())
# Out:
# Total loss -920357.39072
# C:\Users\madha\AppData\Local\Temp\ipykernel_14284\2053852139.py:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_profit=df[df['profit'] < 0].sum()

# %%
net_profit=profit-loss
print('Net profit is ',net_profit)
# Out:
# Net profit is  3309749.60272
